# %%
from ase.io import read, write
from ase import build
from ase.visualize import view
import numpy as np

# %%
dickite = read('Dickite.xyz')
view(dickite, viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="0.00 3.57 0.57">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.941 0.784 0.627" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.11">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.81 5.37 7.72">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.941 0.784 0.627" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.11">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
# ...

# %%
build_cell = np.array([[2,0,0],[0,2,0],[0,0,1]])
new_dickite = build.make_supercell(dickite, build_cell)

# %%
write('')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="0.00 3.57 0.57">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.941 0.784 0.627" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.11">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.81 5.37 7.72">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.941 0.784 0.627" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.11">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
# ...
